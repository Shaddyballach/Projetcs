# %%
# Step 1 : import the relevant libraries

import pandas as pd      # pd is the alias for panda
import numpy as np       # np is the alias for numpy

# %%
# Step 2 : read the file onto the Jupiter Notebook

df = pd.read_csv(r'C:\Users\DELL\Documents\Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
# 1. This dataset is a Comma Separated Values File (.csv)

# %%
# Step 3: View Data Summary:

df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
# ...

# %%
# 2. This data set has 506 rows x 15 columns

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
q3,q1 = np.percentile(df,[75,25])
iqr = q3-q1
iqr
# Out:
# 43.8

# %%
# Standard deviation
df.std()
# Out:
# Unnamed: 0    146.213884
# crim            8.601545
# zn             23.322453
# indus           6.860353
# chas            0.253994
# nox             0.115878
# rm              0.702617
# age            28.148861
# dis             2.105710
# rad             8.707259
# tax           168.537116
# ptratio         2.164946
# black          91.294864
# lstat           7.141062
# medv            9.197104
# dtype: float64

# %%
# Mean
df.mean()
# Out:
# Unnamed: 0    253.500000
# crim            3.613524
# zn             11.363636
# indus          11.136779
# chas            0.069170
# nox             0.554695
# rm              6.284634
# age            68.574901
# dis             3.795043
# rad             9.549407
# tax           408.237154
# ptratio        18.455534
# black         356.674032
# lstat          12.653063
# medv           22.532806
# dtype: float64

# %%
# Median
df.median()
# Out:
# Unnamed: 0    253.50000
# crim            0.25651
# zn              0.00000
# indus           9.69000
# chas            0.00000
# nox             0.53800
# rm              6.20850
# age            77.50000
# dis             3.20745
# rad             5.00000
# tax           330.00000
# ptratio        19.05000
# black         391.44000
# lstat          11.36000
# medv           21.20000
# dtype: float64

# %%
# Mode
df.mode()
# Out:
#      Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  \
# 0             1   0.01501  0.0   18.1   0.0  0.538  5.713  100.0  3.4952
# 1             2  14.33370  NaN    NaN   NaN    NaN  6.127    NaN     NaN
# 2             3       NaN  NaN    NaN   NaN    NaN  6.167    NaN     NaN
# 3             4       NaN  NaN    NaN   NaN    NaN  6.229    NaN     NaN
# 4             5       NaN  NaN    NaN   NaN    NaN  6.405    NaN     NaN
# ..          ...       ...  ...    ...   ...    ...    ...    ...     ...
# 501         502       NaN  NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 502         503       NaN  NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 503         504       NaN  NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 504         505       NaN  NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 505         506       NaN  NaN    NaN   NaN    NaN    NaN    NaN     NaN
#
#       rad    tax  ptratio  black  lstat  medv
# ...

# %%
# Various data types in the dataset include:
# 1.Interger
# 2.Float
# 3.String
